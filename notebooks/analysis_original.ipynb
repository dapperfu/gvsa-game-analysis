# %% [markdown]
# # GVSA Data Analysis
#
# This notebook provides a starting point for analyzing GVSA soccer data. It includes:
# - Database connection and schema exploration
# - Basic statistics about the data
# - Sample data from each table

# %%
# Import required libraries
import sys
from pathlib import Path

# Database and ORM
from pony.orm import db_session, select, count
from models import db, Season, Division, Team, TeamSeason, Match, Club
from db_pony import GVSA_Database

# Data analysis
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Set up plotting
# %matplotlib inline
plt.style.use('seaborn-v0_8-darkgrid')
sns.set_palette("husl")

print("Libraries imported successfully")
# Out:
# Libraries imported successfully

# %% [markdown]
# ## Connect to Database

# %%
# Connect to the database
db_path = "/projects/gvsa_scrape/gvsa_data2.db"

# Explicitly bind the database (required for Jupyter notebooks)
# This ensures the database is properly bound even if cells are run multiple times
try:
    # Unbind if already bound to a different database
    if hasattr(db, 'provider') and db.provider:
        db.disconnect()
except Exception:
    pass

# Bind to the database
db.bind(provider='sqlite', filename=db_path, create_db=False)
db.generate_mapping(create_tables=False)

# Initialize database connection (for compatibility)
gvsa_db = GVSA_Database(db_path)

print(f"Connected to database: {db_path}")
print(f"Database file exists: {Path(db_path).exists()}")

# Verify connection by checking if we can access the database
with db_session:
    season_count = count(s for s in Season)
    print(f"Seasons in database: {season_count}")
# Out:
# Connected to database: /projects/gvsa_scrape/gvsa_data2.db
# Database file exists: True
# Seasons in database: 71

# %% [markdown]
# ## Database Schema
#
# The database contains the following entities:
# - **Season**: Soccer seasons (Fall/Spring)
# - **Division**: Divisions within seasons (e.g., "U11 Boys 5th Division")
# - **Club**: Soccer clubs (e.g., "NUSC", "Rapids FC")
# - **Team**: Team entities that persist across seasons
# - **TeamSeason**: Team participation in specific division/season with statistics
# - **Match**: Soccer matches with scores and scheduling

# %%
# Display database schema information
with db_session:
    print("Database Schema:")
    print("=" * 60)
    
    # Get counts for each entity
    stats = {
        'Seasons': count(s for s in Season),
        'Divisions': count(d for d in Division),
        'Clubs': count(c for c in Club),
        'Teams': count(t for t in Team),
        'Team Seasons': count(ts for ts in TeamSeason),
        'Matches': count(m for m in Match),
    }
    
    for entity, count_val in stats.items():
        print(f"{entity:20s}: {count_val:>8,}")
    
    print("=" * 60)
# Out:
# Database Schema:
# ============================================================
# Seasons             :       71
# Divisions           :    1,606
# Clubs               :      766
# Teams               :    1,261
# Team Seasons        :   12,096
# Matches             :        0
# ============================================================

# %% [markdown]
# ## Sample Data
#
# Let's look at sample data from each table:

# %%
# Sample Seasons
with db_session:
    print("Sample Seasons:")
    print("-" * 60)
    seasons = select(s for s in Season).order_by(Season.scraped_at.desc()).limit(5)
    for season in seasons:
        # Display just the season_name (e.g., "Fall 2025")
        print(f"  {season.season_name} ({season.season_type})")
    print()
# Out:
# Sample Seasons:
# ------------------------------------------------------------
#   Fall 2020 (2020/2021) - F
#   Fall 2020 (2020/2021) - F
#   Fall 2020 (2020/2021) - F
#   Spring 2021 (2020/2021) - F
#   Spring 2021 (2020/2021) - F

# %%
# Sample Divisions
with db_session:
    print("Sample Divisions:")
    print("-" * 60)
    divisions = select(d for d in Division).order_by(Division.division_name).limit(10)
    for div in divisions:
        print(f"  {div.division_name} - {div.season.season_name}")
    print()
# Out:
# Sample Divisions:
# ------------------------------------------------------------
#   Gazelle Sports U12 Boys Elite - Fall 2012
#   Gazelle Sports U12 Boys Elite - Spring 2013
#   Gazelle Sports U12 Girls Elite - Fall 2012
#   Gazelle Sports U12 Girls Elite - Spring 2013
#   Gazelle Sports U13 Boys Elite - Fall 2012
#   Gazelle Sports U13 Boys Elite - Spring 2013
#   Gazelle Sports U13 Girls Elite - Spring 2013
#   Gazelle Sports U14 Boys Elite - Fall 2012
#   Gazelle Sports U14 Boys Elite - Spring 2013
#   Gazelle Sports U14 Girls Elite - Fall 2012

# %%
# Sample Clubs
with db_session:
    print("Sample Clubs:")
    print("-" * 60)
    clubs = select(c for c in Club).order_by(Club.name)
    for club in clubs:
        team_count = count(t for t in Team if t.club == club)
        print(f"  {club.name} ({team_count} teams)")
    print()
# Out:
# Sample Clubs:
# ------------------------------------------------------------
#   "OLE SOCCER OLE SC "" BOYS" (1 teams)
#   ' LASSO RASCALS (1 teams)
#   / Miller - (1 teams)
#   / Zwak - (1 teams)
#   AGUILAS OF GRAND RAPIDS GALAXY (1 teams)
#   AYSO United ADA HS Girls (1 teams)
#   AYSO United Ada (3 teams)
#   AYSO United BYR (4 teams)
#   AYSO United BYR HS Girls (1 teams)
#   AYSO United CAL (1 teams)
#   AYSO United CED (1 teams)
#   AYSO United GEO (4 teams)
#   AYSO United GEO HS Girls (1 teams)
#   AYSO United HS Boys (1 teams)
#   AYSO United HS Girls Select (1 teams)
#   Aguilas (1 teams)
#   Aguilas / - (1 teams)
#   Alliance / (1 teams)
#   Alliance Academy (0 teams)
#   Alliance Academy Kicks (1 teams)
#   Alliance Academy Newaygo Co (1 teams)
#   Alliance Boys (2 teams)
#   Alliance FC (7 teams)
#   Alliance FC / (1 teams)
#   Alliance FC ALLIANCE (2 teams)
#   Alliance FC ALLIANCE BOYS B (1 teams)
#   Alliance FC ALLIANCE GIRLS (1 teams)
#   Alliance FC BOYS (1 teams)
#   Alliance FC GIRLS (1 teams)
#   Alliance FC Orange (1 teams)
#   Alliance Fremont (1 teams)
#   Alliance GR (3 teams)
#   Alliance GR 15A (1 teams)
#   Alliance Girls (1 teams)
#   Alliance Newaygo (1 teams)
#   Alliance Shoreline (1 teams)
#   Athletic Jaier FC (2 teams)
#   Avengers - (1 teams)
#   BC Fire SC (6 teams)
#   Bandidas (2 teams)
#   Bandidas / (1 teams)
#   Bandidos / - (1 teams)
#   Boys NUSC (1 teams)
#   Breakers (2 teams)
#   CADILLAC CHARGERS (1 teams)
#   CADILLAC DYNAMITE (1 teams)
#   CADILLAC FRENZY (1 teams)
#   CADILLAC FUSION (1 teams)
#   CADILLAC SA (1 teams)
#   CADILLAC STRIKERS (1 teams)
#   CADILLAC THUNDER (1 teams)
#   CADILLAC UNITED (1 teams)
#   CADILLAC VIKINGS (1 teams)
#   CADILLAC VIPERS (1 teams)
#   CADILLAC WILD (1 teams)
#   CASSA (11 teams)
#   CASSA - BARR (1 teams)
#   CASSA - BRANDIMORE (1 teams)
#   CASSA - BRAY (1 teams)
#   CASSA - BROWN (1 teams)
#   CASSA - BUCHNER (1 teams)
#   CASSA - FRILEN (1 teams)
#   CASSA - HEARTH (1 teams)
#   CASSA - MALON (1 teams)
#   CASSA - OUTWIN (1 teams)
#   CASSA - TATE (1 teams)
#   CASSA - WALKER (1 teams)
#   CASSA - WEEKS (1 teams)
#   CASSA Boys (1 teams)
#   CASSA TRI-HAWKS (3 teams)
#   CASSA TRI-HAWKS - BRANDIMORE (1 teams)
#   CASSA TRI-HAWKS - BUCHNER (1 teams)
#   CASSA TRI-HAWKS - HOLTROP (1 teams)
#   CASSA TRI-HAWKS - KENYON (1 teams)
#   CASSA TRI-HAWKS - MAIN (1 teams)
#   CASSA TRI-HAWKS - RUMSEY (1 teams)
#   CASSA TRI-HAWKS - WALKER (1 teams)
#   CATS FC (5 teams)
#   CATS FC CATS (1 teams)
#   CENTRAL SHORELINE (3 teams)
#   CENTRAL SHORELINE (1997/1998) (1 teams)
#   COED NUSC (1 teams)
#   COSTA UNITED FC (2 teams)
#   COSTA UNITED FC RIPTIDE (1 teams)
#   COSTA UNITED FC U- GIRLS (1 teams)
#   COSTA UNITED FC-- (1 teams)
#   COSTA UNITED FC-TIGER SHARKS (1 teams)
#   CREW KENTWOOD (4 teams)
#   CREW RASCALS (2 teams)
#   CREW WEST (1 teams)
#   CSA Crush (2 teams)
#   CSA Wild (3 teams)
#   Cadillac (3 teams)
#   Cadillac Breakaway (1 teams)
#   Cadillac Chaos (1 teams)
#   Cadillac Crush (1 teams)
#   Cadillac ER Fire (1 teams)
#   Cadillac Storm (1 teams)
#   Cadillac TBAYS North Storm (1 teams)
#   Cadillac Wild JR's (1 teams)
#   Central Shoreline U17G (1 teams)
#   Central Shoreline Wolverines99 (1 teams)
#   Chaotic Storm (1 teams)
#   Chargers - (1 teams)
#   Costa - (2 teams)
#   Costa COSTA UNITED FC (1 teams)
#   Costa COSTA UNITED SC COSTA UN (1 teams)
#   Costa CYCLONES (1 teams)
#   Costa FC / (1 teams)
#   Costa Hurricanes (1 teams)
#   Costa United FC COSTA UNITED F (1 teams)
#   Costa United FC-CYCLONES (1 teams)
#   Costa United FC-HURRICANES (1 teams)
#   Costa United FC-STING RAYS (1 teams)
#   Crusaders - (1 teams)
#   DBSS (1 teams)
#   DBSS Sting (2 teams)
#   ER Fire (1 teams)
#   ER United (4 teams)
#   East FC (4 teams)
#   East FC HSG Azul (1 teams)
#   FASSA (2 teams)
#   FASSA 072 (1 teams)
#   FC Elite (1 teams)
#   FFC Knights (1 teams)
#   FFC Knights - (3 teams)
#   FFC Knights - - (1 teams)
#   FFC Knights / - (1 teams)
#   FRUITPORT FIRE (1 teams)
#   FRUITPORT FIRE- (1 teams)
#   FRUITPORT FIRE- ORANGE (1 teams)
#   FRUITPORT SOCER FRUITPORT FIRE (1 teams)
#   Fenwick Football Club (1 teams)
#   Flying Kick (1 teams)
#   Force SC (6 teams)
#   Fremont (1 teams)
#   Fury FC (2 teams)
#   Fury FC Grey (1 teams)
#   Fury FC U12B-Franklin (1 teams)
#   Fury FC U12B-Hazekamp (1 teams)
#   Fury FC- Arnold (1 teams)
#   Fury FC- Belasco (1 teams)
#   Fury FC- Cooper (1 teams)
#   Fury FC- Firestone (1 teams)
#   Fury FC- Hall (1 teams)
#   Fury FC- McClain (1 teams)
#   Fury FC- Merkins (1 teams)
#   Fury FC- Oppenhuizen (1 teams)
#   Fury FC- Skodack (1 teams)
#   Fury FC-Hernandez (1 teams)
#   Fury FC-Stanberry (1 teams)
#   Fury FC-Wescott (1 teams)
#   Fury U10B Ludlum (1 teams)
#   Fury U10B Skodack (1 teams)
#   GALAXY SATURN (1 teams)
#   GR Crew Jrs (5 teams)
#   GRAND RAPIDS 1995 (1 teams)
#   GRCJ (7 teams)
#   GRCJ GREY (2 teams)
#   GRCJ O6 (1 teams)
#   GRCJ PLATINUM (1 teams)
#   GRCJ WEST (4 teams)
#   Galaxy (4 teams)
#   Galaxy Jupiter (1 teams)
#   Galaxy Stars (1 teams)
#   Galaxy Sun (1 teams)
#   Girls NUSC (1 teams)
#   Grand Ledge SC (2 teams)
#   Grand Ledge SC Boys - Ward (1 teams)
#   Grand Ledge SC Girls-Navy (1 teams)
#   Grand Ledge Soccer Club (1 teams)
#   Grand Ledge U15B (1 teams)
#   Grant FC (1 teams)
#   Guardians (1 teams)
#   Guerrero (1 teams)
#   HASTINGS FC (3 teams)
#   HASTINGS FC - / FLIKKEMA (1 teams)
#   HASTINGS FC - / GOLE (1 teams)
#   HASTINGS FC - / JILES (1 teams)
#   HASTINGS FC - / KENDALL (1 teams)
#   HASTINGS FC - / MEREDITH (1 teams)
#   HASTINGS FC - / TEUNESSEN (1 teams)
#   HASTINGS FC - NEMETZ (1 teams)
#   HJR SC U16G E (1 teams)
#   Haslett (1 teams)
#   Haslett 08b (1 teams)
#   Haslett Navy (1 teams)
#   Haslett SC u12 B (1 teams)
#   Haslett Soccer Club (1 teams)
#   Haslett U14G (1 teams)
#   Haslett Vikings (1 teams)
#   Hastings FC / Roderick (1 teams)
#   Holland (7 teams)
#   Holland / (2 teams)
#   Holland Rovers (2 teams)
#   Holland Rovers Arrows (1 teams)
#   Holland Rovers Bandidas (1 teams)
#   Holland Rovers Eagles (1 teams)
#   Holland Rovers Storm (1 teams)
#   Holland Rovers-Guerrero (1 teams)
#   Holt Jr Rams Girls (1 teams)
#   Hornets (1 teams)
#   JACS The Legion (1 teams)
#   JACS Torpedoes (1 teams)
#   Jaier (4 teams)
#   Junior Ryderz / - (1 teams)
#   Kalamazoo (4 teams)
#   Kalamazoo 1998 (1 teams)
#   Kalamazoo 1999 (1 teams)
#   Kentwood Falcons (5 teams)
#   Kingdom (6 teams)
#   Kingdom Select (2 teams)
#   Knights - (1 teams)
#   LAKERS (8 teams)
#   LAKERS FREMONT (1 teams)
#   LAKERS FREMONT - WARD (1 teams)
#   LAKERS NEWAYGO - PAINTER (1 teams)
#   LAKESHORE PREMIER SC (1 teams)
#   LASSO (13 teams)
#   LASSO B (1 teams)
#   LASSO BOYS (2 teams)
#   LASSO GIRLS (2 teams)
#   LPSC McAllister (1 teams)
#   LPSC McKessy (1 teams)
#   LSC / Boys (1 teams)
#   LSC Boys (3 teams)
#   LSC Boys Orange (1 teams)
#   LSC Girls (1 teams)
#   Lakeshore / - (1 teams)
#   Lakeshore FC (31 teams)
#   Lakeshore FC Acad W (1 teams)
#   Lakeshore FC Andrews (1 teams)
#   Lakeshore FC Andrews Sky (1 teams)
#   Lakeshore FC Boyer (1 teams)
#   Lakeshore FC Edwards (1 teams)
#   Lakeshore FC Ellison (1 teams)
#   Lakeshore FC Goldman (1 teams)
#   Lakeshore FC Hutchison (1 teams)
#   Lakeshore FC Krapohl (1 teams)
#   Lakeshore FC Londot (1 teams)
#   Lakeshore FC Nardin (1 teams)
#   Lakeshore FC Navy (1 teams)
#   Lakeshore FC PA (1 teams)
#   Lakeshore FC PA Saurbaugh (1 teams)
#   Lakeshore FC Sky (1 teams)
#   Lakeshore FC Sportell (1 teams)
#   Lakeshore FC Teal (1 teams)
#   Lakeshore FC Wooten (1 teams)
#   Lakeshore SC ANDREWS (1 teams)
#   Lakeshore SC Acad Foulkes (1 teams)
#   Lakeshore SC Acad Gillis (1 teams)
#   Lakeshore SC Academy Beeck (1 teams)
#   Lakeshore SC BOYER / (1 teams)
#   Lakeshore SC BUITENHUIS / (1 teams)
#   Lakeshore SC BUURSMA (1 teams)
#   Lakeshore SC Bradford-Royle (1 teams)
#   Lakeshore SC DEYOUNG (1 teams)
#   Lakeshore SC Dean (1 teams)
#   Lakeshore SC FERRIS (1 teams)
#   Lakeshore SC FOULKES / (1 teams)
#   Lakeshore SC GIROUX (1 teams)
#   Lakeshore SC HALLBERG (1 teams)
#   Lakeshore SC HARDEBECK (1 teams)
#   Lakeshore SC HINES (1 teams)
#   Lakeshore SC Hardy (1 teams)
#   Lakeshore SC JORDAN (1 teams)
#   Lakeshore SC LARANJA (1 teams)
#   Lakeshore SC McKessy (1 teams)
#   Lakeshore SC Mey Acad. (1 teams)
#   Lakeshore SC OOSTERBAAN (1 teams)
#   Lakeshore SC PROCTOR (1 teams)
#   Lakeshore SC SPRINGER (1 teams)
#   Lakeshore SC STROHMEYER (1 teams)
#   Lakeshore SC Stehouwer Acad (1 teams)
#   Lakeshore SC TEJCHMA (1 teams)
#   Lakeshore SC Tuin (1 teams)
#   Lakeshore SC W. Diffenderfe (1 teams)
#   Lansing (1 teams)
#   Los (1 teams)
#   Los Ryderz / - (1 teams)
#   MFA 616 (1 teams)
#   MFA GR (3 teams)
#   MFA GR Supplemental Select (1 teams)
#   MFA GR Volt (1 teams)
#   MFA NS (2 teams)
#   MFA NS Volt (1 teams)
#   MFA Revolution GR (3 teams)
#   MFA Revolution GR Gray (1 teams)
#   MFA Revolution GR Supp Sel (1 teams)
#   MFA Revolution GR Volt (1 teams)
#   MFA Revolution Gray (1 teams)
#   MFA Revolution LS (2 teams)
#   MFA Revolution NS (2 teams)
#   MFA Revolution NS Supp (1 teams)
#   MFA Revolution NS Volt (1 teams)
#   MFA SS (1 teams)
#   MFA SS / (1 teams)
#   MFA SS / Volt (1 teams)
#   MFA Tricks (1 teams)
#   MFJ (39 teams)
#   MFJ / (8 teams)
#   MFJ / White/Downey (1 teams)
#   MFJ Academy (1 teams)
#   MFJ Grey (2 teams)
#   MFJ Navy (2 teams)
#   MFJ Pre Academy Bertalan (1 teams)
#   MFJ Pre Academy Muckle (1 teams)
#   MFJ Red/Andrade (1 teams)
#   MFJ Red/Kerker (1 teams)
#   MFJ Riemersma (1 teams)
#   MFJ White/Downey (1 teams)
#   MI FIRE JR'S / Red/Kerker (1 teams)
#   MI FIRE JR'S Blue/Brown (1 teams)
#   MI FIRE JR'S Blue/Whitehous (1 teams)
#   MI FIRE JR'S Red/Andrae (1 teams)
#   MI FIRE JR'S Red/Bertalan (1 teams)
#   MI FIRE JR'S Red/Cronkrigh (1 teams)
#   MI FIRE JR'S Red/Garcia (1 teams)
#   MI FIRE JR'S Red/Gibson (1 teams)
#   MI FIRE JR'S Red/Moore (1 teams)
#   MI FIRE JR'S Red/Muckle (1 teams)
#   MI FIRE JR'S Red/Wood (1 teams)
#   MI FIRE JR'S U117/ White/Den (1 teams)
#   MI FIRE JR'S White/Downey (1 teams)
#   MI FIRE JR'S White/Smith (1 teams)
#   MI FIRE JR'S White/Vantine (1 teams)
#   MI FIRE JR'S White/Zuber (1 teams)
#   MI Fire Jr's Red/Sargent (1 teams)
#   MI Power (3 teams)
#   MI Power / (2 teams)
#   MI Rangers FC (3 teams)
#   MI Rangers FC Gray (1 teams)
#   MI Rangers FC Supplemental (1 teams)
#   MICHIGAN FIRE JR'S (1 teams)
#   MICHIGAN FIRE JR'S () (1 teams)
#   MICHIGAN FIRE JR'S () BL (1 teams)
#   MICHIGAN FIRE JR'S () WH (1 teams)
#   MICHIGAN FIRE JR'S / (1 teams)
#   MICHIGAN FIRE JR'S / () (1 teams)
#   MICHIGAN FIRE JR'S /9 (1 teams)
#   MICHIGAN FIRE JR'S MICHIGAN FI (1 teams)
#   MICHIGAN FIRE JR'S RED/BIRD (1 teams)
#   MICHIGAN FIRE JR'S RED/Fett (1 teams)
#   MICHIGAN FIRE JR'S RED/KERK (1 teams)
#   MICHIGAN FIRE JR'S WHITE/VA (1 teams)
#   MICHIGAN FIRE JRS GREY/MIED (1 teams)
#   MICHIGAN FIRE JRS RED/HOLTR (1 teams)
#   MICHIGAN FIRE JRS RED/VANDU (1 teams)
#   MICHIGAN FIRE JRS WHITE/KER (1 teams)
#   MICHIGAN PDA / DIABLOS (1 teams)
#   MP FC (4 teams)
#   MUSKEGON LAKERS - TROYER (1 teams)
#   MUSKEGON LAKERS - WOOD (1 teams)
#   MUSKEGON LAKERS TABLER (1 teams)
#   Mannes (1 teams)
#   Maroons Holland (1 teams)
#   Marshall (1 teams)
#   Marshall Redhawks (1 teams)
#   Michigan (1 teams)
#   Michigan PDA / AZTECAS (1 teams)
#   Michigan PDA / TIGERS (1 teams)
#   Michigan PDA / TOROS (1 teams)
#   Michigan PDA / WARRIORS (1 teams)
#   Midwest United B Grey (1 teams)
#   Midwest United DBSS (1 teams)
#   Midwest United FC (2 teams)
#   Midwest United FC Academy (1 teams)
#   Midwest United FC Charcoal (1 teams)
#   Midwest United FC K-zoo (1 teams)
#   Midwest United FC KW (2 teams)
#   Midwest United FC KW Plati (1 teams)
#   Midwest United FC Lakeshore (1 teams)
#   Midwest United FC Navy (1 teams)
#   Midwest United FC River Oaks (1 teams)
#   Midwest United FC Riverside (1 teams)
#   Midwest United FC Royal (1 teams)
#   Midwest United FC Wyoming (1 teams)
#   Midwest United SCOR (1 teams)
#   Midwest United SCOR Orange (1 teams)
#   Monarcas / - (1 teams)
#   Muskegon (4 teams)
#   Muskegon LAKERS FREMONT-BYRNE (1 teams)
#   Muskegon Lakers (2 teams)
#   Muskegon Lakers - BAILEY (1 teams)
#   Muskegon Lakers - HARRIS (1 teams)
#   Muskegon Lakers - HOLMES (1 teams)
#   Muskegon Lakers - KOEKKOEK (1 teams)
#   Muskegon Lakers - SCHULTZ (1 teams)
#   Muskegon Lakers - T. PRINCE (1 teams)
#   Muskegon Lakers - YIN (1 teams)
#   Muskegon Lakers GIRLS - WO (1 teams)
#   Muskegon Lakers Muskegon Laker (1 teams)
#   NEWAYGO CO. LAKERS - MULDER (1 teams)
#   NEWAYGO CO. LAKERS - PAINTER (1 teams)
#   NEWAYGO LAKERS- WARD (1 teams)
#   NORTHLAND UNITED (6 teams)
#   NORTHLAND UNITED SC NORTHLAND (1 teams)
#   NORTHSTAR ACADEMY (1 teams)
#   NUSC (6 teams)
#   NUSC Boys (1 teams)
#   NUSC Girls (2 teams)
#   NUSC Lady (1 teams)
#   NUSC Lil (1 teams)
#   Northland United / (1 teams)
#   Northland United Balanda (1 teams)
#   Northland United Boys (1 teams)
#   Northland United Girls (1 teams)
#   Northland United Tucci (1 teams)
#   Northland United Westerkamp (1 teams)
#   Northland United- Strohkirch (1 teams)
#   Northland United-Coulson (1 teams)
#   Northland United-McAdams (1 teams)
#   Northland United-Rider (1 teams)
#   Northstar (1 teams)
#   Northwest Screaming Eagles (1 teams)
#   OLE HOLLAND (1 teams)
#   OLE SC (14 teams)
#   OLE SC BOYS ACADEMY (1 teams)
#   OSC (9 teams)
#   Oakridge SC (2 teams)
#   PASS FC (21 teams)
#   PASS FC - KENOWA (1 teams)
#   PASS FC / (1 teams)
#   PASS FC / BG (1 teams)
#   PASS FC / Spring (1 teams)
#   PASS FC CLARK (1 teams)
#   PASS FC GALLOWAY (1 teams)
#   PASS FC HS Boys (1 teams)
#   PASS FC HS Boys - (1 teams)
#   PASS FC HS Boys - Navy (1 teams)
#   PASS FC HS Girls (2 teams)
#   PASS FC HS Girls Orange (1 teams)
#   PASS FC PASS GIRLS (1 teams)
#   PASS FC U19B (1 teams)
#   PASS FC U19G (1 teams)
#   PASS-Hawks GR (1 teams)
#   PASS-Wolves GR (1 teams)
#   PDA AZTECAS (1 teams)
#   PDA TIGERS (1 teams)
#   PDA TOROS (2 teams)
#   PDA WARRIORS (2 teams)
#   Phoenix - (1 teams)
#   Portage Power (1 teams)
#   Portage SC (9 teams)
#   RANGERS BILLIN (1 teams)
#   RANGERS VRYHOF (1 teams)
#   RANGERS ZASTROW (1 teams)
#   RAPIDS FC (8 teams)
#   RAPIDS FC RAPIDS (3 teams)
#   RASC (8 teams)
#   RCFC (7 teams)
#   RCR DRIVE (1 teams)
#   RCR FC DRIVE (1 teams)
#   RCR FC FEVER (1 teams)
#   RCR FC FRENZY (1 teams)
#   RCR FC RAVE (1 teams)
#   RCR FC SPIRIT (1 teams)
#   RCR FEVER (1 teams)
#   RCR RAVE (1 teams)
#   RCRFC Fury (1 teams)
#   RIVER CITY RASCALS (1 teams)
#   RP BOMBERS (1 teams)
#   RP LADY ROCKETS (1 teams)
#   RP NORTHSHORE LAUNCH (1 teams)
#   RP RC Breakers (3 teams)
#   RP RC Breakers - Singleton (1 teams)
#   RP RC Breakers - Tryska (1 teams)
#   RP RC United (2 teams)
#   RP ROCKET CITY BOMBERS (1 teams)
#   RP ROCKET CITY BREAKERS (1 teams)
#   RP ROCKET CITY ROCKETS (1 teams)
#   RP ROCKETS (2 teams)
#   RP Rocket City United U10B (1 teams)
#   RPRC Breakers - Ludlow (1 teams)
#   Rangers (14 teams)
#   Rangers Academy (1 teams)
#   Rapids FC Grey (1 teams)
#   Real Grand (4 teams)
#   Real Grand GRAND RAPIDS (1 teams)
#   Rebels - (1 teams)
#   Red Arrow (4 teams)
#   Resistance - (1 teams)
#   Revolution (2 teams)
#   Revolution - (1 teams)
#   Revolution Volt (2 teams)
#   River Oaks (2 teams)
#   Rovers (2 teams)
#   Rovers-Struikrovers / (1 teams)
#   SCOR (3 teams)
#   SCOR - (1 teams)
#   SCOR --BLACK (1 teams)
#   SCOR -03_ORANGE (1 teams)
#   SCOR LOBOS (2 teams)
#   SCOR MEULENSTEEN BOYS BLK (1 teams)
#   SCOR MEULENSTEEN BOYS ORNG (1 teams)
#   SCOR MEULENSTEEN GIRLS BLK (1 teams)
#   SCOR MEULENSTEEN GIRLS ORNG (1 teams)
#   SCOR Meulensteen (1 teams)
#   SCOR Meulensteen Academy (1 teams)
#   SCOR Meulensteen Orange (1 teams)
#   SCOR SCOR--BLACK (1 teams)
#   SCOR- (1 teams)
#   SCOR- Chapines GR (1 teams)
#   SCOR-Meulensteen Black (1 teams)
#   SCOR-Meulensteen Grey (1 teams)
#   SCOR-Meulensteen Orange (1 teams)
#   SCOR-Meulensteen Orange / (1 teams)
#   SCOR-Meulensteen White (1 teams)
#   SW Michigan (1 teams)
#   SWM (1 teams)
#   SWM Kickers (5 teams)
#   SWM Kickers Blk (1 teams)
#   Sailors (5 teams)
#   SouthWest Michigan (1 teams)
#   Sting (2 teams)
#   Storm (1 teams)
#   Strikers SEVERANCE (1 teams)
#   StruikRovers (1 teams)
#   Sturgis SC (1 teams)
#   TASC (7 teams)
#   TASC - BAKER (1 teams)
#   TASC - CURTIS (1 teams)
#   TASC - REPLOGLE (1 teams)
#   TASC - RODAS98/ (1 teams)
#   TASC - ZICCARELLO (1 teams)
#   TASC BREMER (1 teams)
#   TASC Barnes (1 teams)
#   TASC Bonnema (1 teams)
#   TASC Burgess (1 teams)
#   TASC CURTIS / (1 teams)
#   TASC Cawagas (1 teams)
#   TASC Corpe (1 teams)
#   TASC Curtis (1 teams)
#   TASC DeWent (1 teams)
#   TASC Feldpausch (1 teams)
#   TASC Force (1 teams)
#   TASC Gole (1 teams)
#   TASC Goudzwaard (1 teams)
#   TASC HILDEBRAND (1 teams)
#   TASC Hardy (1 teams)
#   TASC Hendricks (1 teams)
#   TASC Hodges (1 teams)
#   TASC Kiel (1 teams)
#   TASC Lampton (1 teams)
#   TASC Makowski (1 teams)
#   TASC Middleton (1 teams)
#   TASC Nichols (1 teams)
#   TASC Nutt (1 teams)
#   TASC Rodas (1 teams)
#   TASC Roderick (1 teams)
#   TASC Rougas (1 teams)
#   TASC SPONABLE (1 teams)
#   TASC STRUMBERGER / (1 teams)
#   TASC Schoenberg (1 teams)
#   TASC Sleeman (1 teams)
#   TASC Snowden (1 teams)
#   TASC Strait (1 teams)
#   TASC Sysko (1 teams)
#   TASC THALER (1 teams)
#   TASC THALER / (1 teams)
#   TASC Winchel (1 teams)
#   TASC Wood (1 teams)
#   TASC YBEMA (1 teams)
#   TASC-HUYSER (1 teams)
#   TASC-MIDDLETTON / (1 teams)
#   TASC-WELZ (1 teams)
#   TBAYS NORTH STORM (1 teams)
#   TBAYS NORTHSTORM (2 teams)
#   TBAYS NORTHSTORM Girls (1 teams)
#   TC STRIKERS - WEXALL (1 teams)
#   TC STRIKERS U10B SCHAENDORF (1 teams)
#   TC STRIKERS U10B VAN ANDEL (1 teams)
#   TC STRIKERS U10G FRENDT (1 teams)
#   TC STRIKERS U10G GAGNON (1 teams)
#   TC STRIKERS U10G KILBRY (1 teams)
#   TC STRIKERS U11B BEACH (1 teams)
#   TC STRIKERS U11B LONDOT (1 teams)
#   TC STRIKERS U11G ANDREWS (1 teams)
#   TC STRIKERS U12G FRITSCHE (1 teams)
#   TC STRIKERS U13B FOULKES (1 teams)
#   TC STRIKERS U13G BUURSMA (1 teams)
#   TC STRIKERS U8B BASIL (1 teams)
#   TC STRIKERS U9B DEAN (1 teams)
#   TC STRIKERS U9B WEIGLE (1 teams)
#   TC STRIKERS U9G CHRISTIANSEN (1 teams)
#   TC Strikers U8B TEJCHMA (1 teams)
#   TC Strikers U9G DULL (1 teams)
#   TC Strikers U9G OOSTERBAAN (1 teams)
#   TCSTRIKERS - / B SPRING R (1 teams)
#   TCSTRIKERS- HIGHSCHOOL WEX (1 teams)
#   TCSTRIKERS- U10G DAHLMAN (1 teams)
#   TCSTRIKERS- U11G DAIGNEAULT (1 teams)
#   TCSTRIKERS-U10B ERIC ANDREWS (1 teams)
#   TCSTRIKERS-U10B GIROUX (1 teams)
#   TCSTRIKERS-U11G MCKESSY (1 teams)
#   TCSTRIKERS-U11G STROHMEYER (1 teams)
#   TCSTRIKERS-U12B HALLBERG (1 teams)
#   TCSTRIKERS-U12G BOYER (1 teams)
#   TCSTRIKERS-U12G VAN DUYN (1 teams)
#   TCSTRIKERS-U13G MAY (1 teams)
#   TCSTRIKERS-U14B LARANJA (1 teams)
#   TCSTRIKERS-U14G COOLING (1 teams)
#   TCSTRIKERS-U8B GLASGOW (1 teams)
#   TCSTRIKERS-U8B KRUEGER (1 teams)
#   TCSTRIKERS-U9B DOUGHERTY (1 teams)
#   TCSTRIKERS-U9B TUBERGEN (1 teams)
#   TCSTRIKERS-U9G BUITENHUIS (1 teams)
#   TCSTRIKERS-U9G STRENG (1 teams)
#   TKO (3 teams)
#   TKO Crew Jr (1 teams)
#   TKO Crew Jrs (2 teams)
#   TKO Crew jr BLK (1 teams)
#   TKO Premier SC (2 teams)
#   TNT Dynamite West (4 teams)
#   TNT Dynamite West 03H (1 teams)
#   TNT Dynamite West TNT (1 teams)
#   TNT GRANDVILLE (1 teams)
#   TNT West (5 teams)
#   TNT West Gray (1 teams)
#   TRI-CITIES STRIKERS- B SCHMIDT (1 teams)
#   TRI-CITIES STRIKERS- COOLING U (1 teams)
#   TRI-CITIES STRIKERS- DAIGNEAUL (1 teams)
#   TRI-CITIES STRIKERS- DOUGHERTY (1 teams)
#   TRI-CITIES STRIKERS- FRITSCHEU (1 teams)
#   TRI-CITIES STRIKERS- HECKU8 (1 teams)
#   TRI-CITIES STRIKERS- HORISTU10 (1 teams)
#   TRI-CITIES STRIKERS- MCKESSYU1 (1 teams)
#   TRI-CITIES STRIKERS- SHERMAN U (1 teams)
#   TRI-CITIES STRIKERS- WEXALL (1 teams)
#   TRI-CITIES STRIKERS-ANDREWS (1 teams)
#   TRI-CITIES STRIKERS-DENISONU12 (1 teams)
#   TRI-CITIES STRIKERS-FLESU11 (1 teams)
#   TRI-CITIES STRIKERS-GIROUXU10 (1 teams)
#   TRI-CITIES STRIKERS-KRUEGERU11 (1 teams)
#   TRI-CITIES STRIKERS-LARANJAU13 (1 teams)
#   TRI-CITIES STRIKERS-TOBAISONU9 (1 teams)
#   TRI-HAWKS RED/ (1 teams)
#   TRI-HAWKS WHITE/ (1 teams)
#   TRI-HAWKS/ (2 teams)
#   Titans (1 teams)
#   Tri Cities- SEVERANCE (1 teams)
#   Tri-Cities (17 teams)
#   Tri-Hawks (2 teams)
#   U12G (1 teams)
#   U7 Boys (1 teams)
#   U9 girls (1 teams)
#   USA (46 teams)
#   USA - BURGER (1 teams)
#   USA - DRIESENGA (1 teams)
#   USA - DYKENS (1 teams)
#   USA - FARRIS (1 teams)
#   USA - GARCA (1 teams)
#   USA - KOSTER (1 teams)
#   USA - LAARMAN (1 teams)
#   USA - LANE (1 teams)
#   USA - LOPEZ (1 teams)
#   USA - PIERCE (1 teams)
#   USA - SALAS (1 teams)
#   USA - SLUITER (1 teams)
#   USA - TERLAAN (1 teams)
#   USA - THEIS (1 teams)
#   USA 12BCB (2 teams)
#   USA BARABAS (1 teams)
#   USA BEIRD (1 teams)
#   USA BENNETT (1 teams)
#   USA BLAIR (1 teams)
#   USA BORGMAN (1 teams)
#   USA BORSKI (1 teams)
#   USA BRINK (1 teams)
#   USA BRITT (1 teams)
#   USA BROERSMA (1 teams)
#   USA Boys (2 teams)
#   USA CHAMBERS (1 teams)
#   USA DENUYL (1 teams)
#   USA DISHNOW (1 teams)
#   USA DOMINGUEZ (1 teams)
#   USA Girls (5 teams)
#   USA Grey (2 teams)
#   USA HUNTER (1 teams)
#   USA HUTZEL (1 teams)
#   USA KERCHER (1 teams)
#   USA LACHTRUPP (1 teams)
#   USA LINART (1 teams)
#   USA LUKAS (1 teams)
#   USA MAAS (1 teams)
#   USA OLSEN (1 teams)
#   USA PA (2 teams)
#   USA PANSE (1 teams)
#   USA RYZENGA (1 teams)
#   USA VANDENEND (1 teams)
#   USA VANDERPLOEG (1 teams)
#   USA VROEGOP (1 teams)
#   USA WISE (1 teams)
#   USA WOOLSEY (1 teams)
#   USA WYMA (1 teams)
#   USA ZIEGELER (1 teams)
#   VARDAR WEST - - HARAMBESIC (1 teams)
#   VARDAR WEST - BOYS (1 teams)
#   VARDAR WEST - GIRLS (1 teams)
#   Van Howe (1 teams)
#   Vardar BOYS (1 teams)
#   Vardar Grand Rapids Boys (1 teams)
#   Vardar Grand Rapids Girls (1 teams)
#   Vardar West (1 teams)
#   Vardar West - BOYS SELECT (1 teams)
#   Vardar West - GIRLS SELECT (1 teams)
#   Vardar West Vardar - (1 teams)
#   Vardar West Vardar - GIRLS (1 teams)
#   Vikings - (1 teams)
#   W MI STORM (19 teams)
#   W MI Storm /02g Maiden (1 teams)
#   W MI Storm /06g Lasser (1 teams)
#   W MI Storm /10g Robinson (1 teams)
#   W MI Storm 00g Wachter (1 teams)
#   W MI Storm 02b Diller (1 teams)
#   W MI Storm 03g Fisher (1 teams)
#   W MI Storm 04b Bowers (1 teams)
#   W MI Storm 04b Johnson (1 teams)
#   W MI Storm 05g Hoffman (1 teams)
#   W MI Storm 05g Rosema (1 teams)
#   W MI Storm 06b Bingham (1 teams)
#   W MI Storm 06b Erndteman (1 teams)
#   W MI Storm 06g McFarland (1 teams)
#   W MI Storm 07b Maiden (1 teams)
#   W MI Storm 07g Fouchea (1 teams)
#   W MI Storm 07g Stanberry (1 teams)
#   W MI Storm 08g Dorsey (1 teams)
#   W MI Storm 09b Leffring (1 teams)
#   W MI Storm 09g Kinney (1 teams)
#   W MI Storm 10b Ladd (1 teams)
#   W MI Storm 11g Visser (1 teams)
#   W MI Storm Meulensteen BLU (1 teams)
#   W MI Storm U19G Lasser (1 teams)
#   W MI Storm U19G Sherman (1 teams)
#   W MI Storm u10/11b Haririan (1 teams)
#   WCSC Girls (1 teams)
#   WM Galaxy (5 teams)
#   WMI Storm Meulensteen (1 teams)
#   WMI Storm Meulensteen ORANG (1 teams)
#   WSW (2 teams)
#   WSW HSB (1 teams)
#   WSW HSB Hart (1 teams)
#   WSW Hart (1 teams)
#   WSW Orange (1 teams)
#   WSW08G (1 teams)
#   WSW10G (1 teams)
#   WSW11B (1 teams)
#   WSW12G (1 teams)
#   WSW13B (1 teams)
#   WSW13G (1 teams)
#   WSW14B (1 teams)
#   WSW15B (1 teams)
#   WSW15G (1 teams)
#   WSW15G Orange (1 teams)
#   WSW16B (1 teams)
#   WSW16G (1 teams)
#   Warriors (1 teams)
#   Warriors - (1 teams)
#   Warriors / - (1 teams)
#   West Coast United (1 teams)
#   West Coast United // (1 teams)
#   West Coast United Blk - RP (1 teams)
#   West Coast United Green-RP (1 teams)
#   WhiteLake Breakers U19B Girls (1 teams)
#   Wildcats (1 teams)
#   YMCA FC / - (1 teams)

# %%
# Sample Teams with Statistics
with db_session:
    print("Sample Team Seasons (with statistics):")
    print("-" * 60)
    team_seasons = select(ts for ts in TeamSeason).order_by(
        TeamSeason.points.desc()
    ).limit(10)
    
    for ts in team_seasons:
        print(f"  {ts.team_name}")
        print(f"    Division: {ts.division.division_name}")
        print(f"    Record: {ts.wins}W-{ts.losses}L-{ts.ties}T, {ts.points} pts")
        print(f"    Goals: {ts.goals_for}GF / {ts.goals_against}GA")
        print()
# Out:
# Sample Team Seasons (with statistics):
# ------------------------------------------------------------
#   MI Rangers FC 15G Black
#     Division: U10 Girls 2nd Division
#     Record: 8W-0L-0T, 24 pts
#     Goals: 41GF / 10GA
#
#   NUSC U13 G Blue Stars
#     Division: U13 Girls 2nd Division
#     Record: 8W-0L-0T, 24 pts
#     Goals: 17GF / 2GA
#
#   Holland Rovers 2010B Red
#     Division: U14 Boys Elite
#     Record: 8W-0L-0T, 24 pts
#     Goals: 30GF / 5GA
#
#   AYSO United BYR 14G
#     Division: U10 Girls 3rd Division
#     Record: 8W-0L-0T, 24 pts
#     Goals: 51GF / 4GA
#
#   CASSA 13G
#     Division: U11G 3rd Division
#     Record: 8W-0L-0T, 24 pts
#     Goals: 26GF / 4GA
#
#   USA 15G Red
#     Division: U9 Girls 2nd Division
#     Record: 8W-0L-0T, 24 pts
#     Goals: 28GF / 3GA
#
#   Holland Rovers Eagles 2010G
#     Division: U14 Girls Elite
#     Record: 8W-0L-0T, 24 pts
#     Goals: 34GF / 4GA
#
#   MFA Revolution NS 15B Black
#     Division: U9 Boys 3rd Division
#     Record: 8W-0L-0T, 24 pts
#     Goals: 67GF / 10GA
#
#   MFA Revolution SS 13B Black
#     Division: U11 Boys 3rd Division
#     Record: 8W-0L-0T, 24 pts
#     Goals: 43GF / 17GA
#
#   USA 11G Red
#     Division: U13 Girls Elite
#     Record: 8W-0L-0T, 24 pts
#     Goals: 22GF / 5GA

# %%
# Sample Matches
with db_session:
    print("Sample Matches:")
    print("-" * 60)
    matches = select(m for m in Match).order_by(Match.date.desc()).limit(10)
    
    for match in matches:
        score_str = ""
        if match.home_score is not None and match.away_score is not None:
            score_str = f" {match.home_score}-{match.away_score}"
        print(f"  {match.home_team.team_name} vs {match.away_team.team_name}{score_str}")
        print(f"    Date: {match.date}, Status: {match.status}")
        print()
# Out:
# Sample Matches:
# ------------------------------------------------------------

# %% [markdown]
# ## Basic Statistics with Pandas

# %%
# Load TeamSeason data into pandas DataFrame
with db_session:
    team_seasons_data = []
    for ts in select(ts for ts in TeamSeason):
        team_seasons_data.append({
            'team_name': ts.team_name,
            'division': ts.division.division_name,
            'season': ts.division.season.season_name,
            'wins': ts.wins,
            'losses': ts.losses,
            'ties': ts.ties,
            'points': ts.points,
            'goals_for': ts.goals_for,
            'goals_against': ts.goals_against,
            'goal_differential': ts.goal_differential,
        })
    
    df_teams = pd.DataFrame(team_seasons_data)

print(f"Loaded {len(df_teams)} team season records")
print(f"\nDataFrame shape: {df_teams.shape}")
print(f"\nColumns: {list(df_teams.columns)}")
df_teams.head(10)
# Out:
# Loaded 12096 team season records
#
# DataFrame shape: (12096, 10)
#
# Columns: ['team_name', 'division', 'season', 'wins', 'losses', 'ties', 'points', 'goals_for', 'goals_against', 'goal_differential']
#                         team_name                division       season  wins  \
# 0              MI Power 11B Black   U13 Boys 2nd Division  Spring 2024     7
# 1         MI Rangers FC 15G Black  U10 Girls 2nd Division  Spring 2024     8
# 2              MI Power 14B Black   U10 Boys 3rd Division  Spring 2024     7
# 3                 CASSA 11B Black   U13 Boys 2nd Division  Spring 2024     6
# 4    SCOR-Meulensteen Orange 2008       U15/16 Boys Elite  Spring 2024     6
# 5      NUSC 2014 U10 G Blue Stars  U10 Girls 2nd Division  Spring 2024     6
# 6  West Coast United 14B Blk - RP   U10 Boys 3rd Division  Spring 2024     5
# 7    Midwest United SCOR 18 Black    U7 Boys 1st Division  Spring 2024     0
# 8         MI Rangers FC 18B Black    U7 Boys 1st Division  Spring 2024     0
# 9              RAPIDS FC GREEN 11   U13 Boys 2nd Division  Spring 2024     6
#
#    losses  ties  points  goals_for  goals_against  goal_differential
# 0       1     0      21         38             16                 20
# 1       0     0      24         41             10                 23
# 2       1     0      21         34             16                 15
# 3       0     2      20         34             13                 19
# 4       1     1      19         19              8                 11
# 5       2     0      18         32              9                 14
# 6       2     1      16         27             18                  9
# 7       0     0       0          0              0                  0
# 8       0     0       0          0              0                  0
# 9       1     1      19         19             12                  7

# %%
# Basic statistics
print("Team Season Statistics:")
print("=" * 60)
print(df_teams[['wins', 'losses', 'ties', 'points', 'goals_for', 'goals_against', 'goal_differential']].describe())
# Out:
# Team Season Statistics:
# ============================================================
#                wins        losses          ties        points     goals_for  \
# count  12096.000000  12096.000000  12096.000000  12096.000000  12096.000000
# mean       2.998099      2.982391      0.852844      9.817378     17.733714
# std        2.354575      2.376668      0.973568      7.181527     12.898469
# min        0.000000      0.000000      0.000000     -3.000000      0.000000
# 25%        1.000000      1.000000      0.000000      3.000000      9.000000
# 50%        3.000000      3.000000      1.000000     10.000000     17.000000
# 75%        5.000000      5.000000      1.000000     16.000000     25.000000
# max        8.000000      8.000000      7.000000     24.000000     90.000000
#
#        goals_against  goal_differential
# count   12096.000000       12096.000000
# mean       17.796627           1.014881
# std        13.661192          11.274519
# min         0.000000         -24.000000
# 25%         9.000000          -6.000000
# 50%        16.000000           0.000000
# 75%        25.000000           8.000000
# max       107.000000          32.000000

# %% [markdown]
# # West Coast United 15B Green RP Analysis
#
# This analysis compares "West Coast United 15B Green RP" to all teams in the 2025 Fall season, with a focus on U11 teams and visualizations showing where the team and all West Coast United teams fall in the distributions.

# %%
# Programmatically search for the target team
target_team_name = "West Coast United 15B Green RP"
target_season = "Fall 2025"

print(f"Searching for team: '{target_team_name}'")
print(f"Target season: {target_season}")
print("=" * 80)

with db_session:
    # Search for the target team (flexible matching)
    search_terms = [
        target_team_name.lower(),
        "west coast united 15b green",
        "west coast united 15b green rp",
        "west coast united 15b green-rp",
    ]
    
    target_team_season = None
    for search_term in search_terms:
        team_seasons = list(select(
            ts for ts in TeamSeason 
            if search_term in ts.team_name.lower() 
            and target_season in ts.division.season.season_name
        ))
        if team_seasons:
            target_team_season = team_seasons[0]
            print(f"Found team: {target_team_season.team_name}")
            print(f"  Division: {target_team_season.division.division_name}")
            print(f"  Season: {target_team_season.division.season.season_name}")
            print(f"  Record: {target_team_season.wins}W-{target_team_season.losses}L-{target_team_season.ties}T")
            print(f"  Points: {target_team_season.points}")
            print(f"  Goals For: {target_team_season.goals_for}")
            print(f"  Goals Against: {target_team_season.goals_against}")
            print(f"  Goal Differential (stored): {target_team_season.goal_differential}")
            print(f"  Goal Differential (calculated): {target_team_season.goals_for - target_team_season.goals_against}")
            print(f"  Note: These values will be used in all visualizations")
            break
    
    if not target_team_season:
        print(f"Warning: Could not find exact match for '{target_team_name}'")
        print("\nSearching for similar teams...")
        # Try broader search
        similar_teams = list(select(
            ts for ts in TeamSeason 
            if "west coast" in ts.team_name.lower()
            and "15b" in ts.team_name.lower()
            and target_season in ts.division.season.season_name
        ))
        if similar_teams:
            print(f"Found {len(similar_teams)} similar teams:")
            for ts in similar_teams:
                print(f"  - {ts.team_name} ({ts.division.division_name})")
            target_team_season = similar_teams[0]  # Use first match
            print(f"\nUsing: {target_team_season.team_name}")
        else:
            print("No similar teams found. Please verify the team name.")
# Out:
# Searching for team: 'West Coast United 15B Green RP'
# Target season: Fall 2025
# ================================================================================
# Found team: West Coast United 15B Green RP
#   Division: U11 Boys 5th Division
#   Season: Fall 2025
#   Record: 0W-8L-0T
#   Points: 0
#   Goals For: 3
#   Goals Against: 48
#   Goal Differential (stored): -20
#   Goal Differential (calculated): -45
#   Note: These values will be used in all visualizations

# %%
# Load all teams for 2025 Fall season
# Initialize DataFrames to empty to prevent errors if season not found
df_fall_2025 = pd.DataFrame()
df_u11 = pd.DataFrame()
df_wcu = pd.DataFrame()

with db_session:
    # Get the Fall 2025 season - try multiple matching strategies
    fall_2025_seasons = list(select(
        s for s in Season 
        if 'Fall' in s.season_name and '2025' in s.year_season
    ))
    
    # Also try matching by season_name directly
    if not fall_2025_seasons:
        fall_2025_seasons = list(select(
            s for s in Season 
            if s.season_name == 'Fall 2025'
        ))
    
    # Try matching by year_season containing 2025
    if not fall_2025_seasons:
        fall_2025_seasons = list(select(
            s for s in Season 
            if 'Fall' in s.season_name and ('2025' in s.season_name or '2025' in s.year_season)
        ))
    
    if not fall_2025_seasons:
        print("Warning: No Fall 2025 season found in database")
        print("Available seasons:")
        for s in select(s for s in Season).order_by(Season.season_name.desc())[:10]:
            print(f"  - {s.season_name}")
    else:
        fall_2025 = fall_2025_seasons[0]
        print(f"Found season: {fall_2025.season_name}")
        
        # Load all team seasons for Fall 2025
        all_fall_2025_data = []
        for ts in select(ts for ts in TeamSeason if ts.division.season == fall_2025):
            all_fall_2025_data.append({
                'team_name': ts.team_name,
                'division': ts.division.division_name,
                'wins': ts.wins,
                'losses': ts.losses,
                'ties': ts.ties,
                'points': ts.points,
                'goals_for': ts.goals_for,
                'goals_against': ts.goals_against,
                'goal_differential': ts.goal_differential,
            })
        
        df_fall_2025 = pd.DataFrame(all_fall_2025_data)
        print(f"\nLoaded {len(df_fall_2025)} teams for Fall 2025")
        
        if len(df_fall_2025) > 0:
            # Filter for U11 teams
            df_u11 = df_fall_2025[df_fall_2025['division'].str.contains('U11', case=False, na=False)].copy()
            print(f"Found {len(df_u11)} U11 teams in Fall 2025")
            
            # Identify West Coast United teams
            df_wcu = df_fall_2025[df_fall_2025['team_name'].str.contains('West Coast', case=False, na=False)].copy()
            print(f"Found {len(df_wcu)} West Coast United teams in Fall 2025")
            
            if len(df_wcu) > 0:
                print("\nWest Coast United teams:")
                for idx, row in df_wcu.iterrows():
                    print(f"  - {row['team_name']} ({row['division']})")
        else:
            print("Warning: No teams found for this season")
# Out:
# Found season: Fall 2024 (2024/2025)
#
# Loaded 7 teams for Fall 2025
# Found 0 U11 teams in Fall 2025
# Found 0 West Coast United teams in Fall 2025

# %%
# Create visualization function for distributions using seaborn
def plot_distribution_with_highlights(df, metric, title, xlabel, 
                                      target_team_name=None, 
                                      wcu_teams=None,
                                      subset_label="All Teams"):
    """
    Plot a distribution histogram with highlights for specific teams using seaborn.
    
    Parameters
    ----------
    df : pd.DataFrame
        DataFrame containing team data
    metric : str
        Column name to plot
    title : str
        Plot title
    xlabel : str
        X-axis label
    target_team_name : str, optional
        Name of the target team to highlight
    wcu_teams : pd.DataFrame, optional
        DataFrame of West Coast United teams to highlight
    subset_label : str
        Label for the subset being plotted
    """
    # Check if DataFrame is empty
    if df is None or len(df) == 0:
        print(f"Warning: No data available for {title}")
        return None, None
    
    # Check if metric column exists
    if metric not in df.columns:
        print(f"Warning: Column '{metric}' not found in DataFrame")
        return None, None
    
    fig, ax = plt.subplots(figsize=(12, 6))
    
    # Use seaborn to plot the main distribution
    sns.histplot(data=df, x=metric, bins=30, alpha=0.6, color='steelblue', 
                 edgecolor='black', kde=False, ax=ax, label=f'{subset_label} (n={len(df)})')
    
    # Highlight West Coast United teams
    if wcu_teams is not None and len(wcu_teams) > 0 and metric in wcu_teams.columns:
        wcu_values = wcu_teams[metric].values
        for val in wcu_values:
            ax.axvline(val, color='orange', linestyle='--', linewidth=2, alpha=0.7)
        # Add annotation for WCU teams
        ax.text(0.02, 0.98, f'West Coast United teams: {len(wcu_teams)}', 
                transform=ax.transAxes, fontsize=10, verticalalignment='top',
                bbox=dict(boxstyle='round', facecolor='orange', alpha=0.3))
    
    # Highlight target team - use EXACT match first, then fallback to contains
    if target_team_name is not None and 'team_name' in df.columns:
        # Try exact match first
        target_row = df[df['team_name'] == target_team_name]
        if len(target_row) == 0:
            # Fallback to contains match
            target_row = df[df['team_name'].str.contains(target_team_name, case=False, na=False)]
        
        if len(target_row) > 0 and metric in target_row.columns:
            target_value = target_row[metric].iloc[0]
            actual_team_name = target_row['team_name'].iloc[0]
            
            # Verify we're using the correct team
            if actual_team_name != target_team_name:
                print(f"Warning: Using '{actual_team_name}' instead of '{target_team_name}'")
            
            ax.axvline(target_value, color='red', linestyle='-', linewidth=3, 
                      label=f'Target: {actual_team_name}')
            # Add text annotation with actual values
            ax.text(0.02, 0.92, f'Target team ({actual_team_name[:30]}...): {target_value}', 
                    transform=ax.transAxes, fontsize=10, verticalalignment='top',
                    bbox=dict(boxstyle='round', facecolor='red', alpha=0.3))
            
            # Calculate percentile
            if len(df) > 0:
                percentile = (df[metric] <= target_value).sum() / len(df) * 100
                ax.text(0.02, 0.86, f'Percentile: {percentile:.1f}%', 
                        transform=ax.transAxes, fontsize=10, verticalalignment='top',
                        bbox=dict(boxstyle='round', facecolor='lightblue', alpha=0.3))
        else:
            print(f"Warning: Could not find target team '{target_team_name}' in DataFrame for metric '{metric}'")
    
    ax.set_xlabel(xlabel, fontsize=12)
    ax.set_ylabel('Number of Teams', fontsize=12)
    ax.set_title(title, fontsize=14, fontweight='bold')
    ax.legend()
    ax.grid(True, alpha=0.3)
    
    plt.tight_layout()
    return fig, ax

# %% [markdown]
# ## Distribution Analysis: U11 Teams in Fall 2025
#
# Compare the target team to all U11 teams in Fall 2025.

# %%
# Get target team data if found - ALWAYS use exact team from database first
target_team_data = None
target_team_name_found = None

# First, try to use the exact team found in Cell 16
if 'target_team_season' in locals() and target_team_season:
    target_team_name_found = target_team_season.team_name
    print(f"Using target team from database: {target_team_name_found}")
    
    # Verify the team exists in the DataFrame with exact match
    if 'df_u11' in locals() and len(df_u11) > 0:
        exact_match = df_u11[df_u11['team_name'] == target_team_name_found]
        if len(exact_match) > 0:
            target_team_data = exact_match.iloc[0]
            print(f"  Found in U11 DataFrame with exact match")
            print(f"  Data: {target_team_data['goals_for']}GF / {target_team_data['goals_against']}GA / {target_team_data['goal_differential']}GD")
        else:
            print(f"  Warning: Team not found in U11 DataFrame")
elif 'df_u11' in locals() and len(df_u11) > 0:
    # Fallback: Try to find in DataFrame with exact match first
    target_mask = df_u11['team_name'].str.contains('west coast united 15b green rp', case=False, na=False)
    if not target_mask.any():
        # Try partial match as last resort
        target_mask = df_u11['team_name'].str.contains('west coast', case=False, na=False) & \
                      df_u11['team_name'].str.contains('15b', case=False, na=False) & \
                      df_u11['team_name'].str.contains('green', case=False, na=False)
    if target_mask.any():
        target_team_data = df_u11[target_mask].iloc[0]
        target_team_name_found = target_team_data['team_name']
        print(f"Found target team in DataFrame: {target_team_name_found}")

# Get WCU teams in U11
if 'df_u11' in locals() and len(df_u11) > 0:
    wcu_u11 = df_u11[df_u11['team_name'].str.contains('West Coast', case=False, na=False)].copy()
else:
    wcu_u11 = pd.DataFrame()

print(f"\nTarget team for visualization: {target_team_name_found}")
print(f"West Coast United teams in U11: {len(wcu_u11)}")
if len(wcu_u11) > 0:
    print("\nWest Coast United U11 teams:")
    for idx, row in wcu_u11.iterrows():
        marker = " <-- TARGET" if row['team_name'] == target_team_name_found else ""
        print(f"  - {row['team_name']} ({row['division']}){marker}")
# Out:
# Target team: West Coast United 15B Green RP
# West Coast United teams in U11: 2
#
# West Coast United U11 teams:
#   - West Coast United 14B Blk - RP (U11 Boys 2nd Division)
#   - West Coast United 14B Green-RP (U11 Boys 5th Division)

# %%
# Goals For (Points For) distribution for U11 teams
if len(df_u11) > 0:
    plot_distribution_with_highlights(
        df_u11, 
        'goals_for', 
        'Goals For Distribution - U11 Teams (Fall 2025)',
        'Goals For',
        target_team_name=target_team_name_found,
        wcu_teams=wcu_u11,
        subset_label="U11 Teams"
    )
    plt.show()

# %%
# Goals Against (Points Against) distribution for U11 teams
if len(df_u11) > 0:
    plot_distribution_with_highlights(
        df_u11, 
        'goals_against', 
        'Goals Against Distribution - U11 Teams (Fall 2025)',
        'Goals Against',
        target_team_name=target_team_name_found,
        wcu_teams=wcu_u11,
        subset_label="U11 Teams"
    )
    plt.show()

# %%
# Goal Differential distribution for U11 teams
if len(df_u11) > 0:
    plot_distribution_with_highlights(
        df_u11, 
        'goal_differential', 
        'Goal Differential Distribution - U11 Teams (Fall 2025)',
        'Goal Differential',
        target_team_name=target_team_name_found,
        wcu_teams=wcu_u11,
        subset_label="U11 Teams"
    )
    plt.show()

# %%
# Points distribution for U11 teams
if len(df_u11) > 0:
    plot_distribution_with_highlights(
        df_u11, 
        'points', 
        'Points Distribution - U11 Teams (Fall 2025)',
        'Points',
        target_team_name=target_team_name_found,
        wcu_teams=wcu_u11,
        subset_label="U11 Teams"
    )
    plt.show()

# %% [markdown]
# ## Distribution Analysis: ALL Teams in Fall 2025
#
# Compare the target team to ALL teams in Fall 2025 (all age groups).

# %%
# Get target team data from all teams - ALWAYS use exact team from database first
target_team_all = None
target_team_name_all = None

# First, try to use the exact team found in Cell 16
if 'target_team_season' in locals() and target_team_season:
    target_team_name_all = target_team_season.team_name
    print(f"Using target team from database: {target_team_name_all}")
    
    # Verify the team exists in the DataFrame with exact match
    if 'df_fall_2025' in locals() and len(df_fall_2025) > 0:
        exact_match = df_fall_2025[df_fall_2025['team_name'] == target_team_name_all]
        if len(exact_match) > 0:
            target_team_all = exact_match.iloc[0]
            print(f"  Found in Fall 2025 DataFrame with exact match")
            print(f"  Data: {target_team_all['goals_for']}GF / {target_team_all['goals_against']}GA / {target_team_all['goal_differential']}GD")
        else:
            print(f"  Warning: Team not found in Fall 2025 DataFrame")
elif 'df_fall_2025' in locals() and len(df_fall_2025) > 0:
    # Fallback: Try to find in DataFrame with exact match first
    target_mask_all = df_fall_2025['team_name'].str.contains('west coast united 15b green rp', case=False, na=False)
    if not target_mask_all.any():
        # Try partial match as last resort
        target_mask_all = df_fall_2025['team_name'].str.contains('west coast', case=False, na=False) & \
                          df_fall_2025['team_name'].str.contains('15b', case=False, na=False) & \
                          df_fall_2025['team_name'].str.contains('green', case=False, na=False)
    if target_mask_all.any():
        target_team_all = df_fall_2025[target_mask_all].iloc[0]
        target_team_name_all = target_team_all['team_name']

if 'df_fall_2025' in locals():
    print(f"\nTarget team for visualization: {target_team_name_all}")
    print(f"Total teams in Fall 2025: {len(df_fall_2025)}")
    if 'df_wcu' in locals():
        print(f"West Coast United teams: {len(df_wcu)}")
else:
    print("Fall 2025 data not loaded. Please run the previous cells first.")

# %%
# Goals For distribution for ALL teams
if len(df_fall_2025) > 0:
    plot_distribution_with_highlights(
        df_fall_2025, 
        'goals_for', 
        'Goals For Distribution - ALL Teams (Fall 2025)',
        'Goals For',
        target_team_name=target_team_name_all,
        wcu_teams=df_wcu,
        subset_label="All Teams"
    )
    plt.show()

# %%
# Goals Against distribution for ALL teams
if len(df_fall_2025) > 0:
    plot_distribution_with_highlights(
        df_fall_2025, 
        'goals_against', 
        'Goals Against Distribution - ALL Teams (Fall 2025)',
        'Goals Against',
        target_team_name=target_team_name_all,
        wcu_teams=df_wcu,
        subset_label="All Teams"
    )
    plt.show()

# %%
# Goal Differential distribution for ALL teams
if len(df_fall_2025) > 0:
    plot_distribution_with_highlights(
        df_fall_2025, 
        'goal_differential', 
        'Goal Differential Distribution - ALL Teams (Fall 2025)',
        'Goal Differential',
        target_team_name=target_team_name_all,
        wcu_teams=df_wcu,
        subset_label="All Teams"
    )
    plt.show()

# %%
# Points distribution for ALL teams
if len(df_fall_2025) > 0:
    plot_distribution_with_highlights(
        df_fall_2025, 
        'points', 
        'Points Distribution - ALL Teams (Fall 2025)',
        'Points',
        target_team_name=target_team_name_all,
        wcu_teams=df_wcu,
        subset_label="All Teams"
    )
    plt.show()

# %% [markdown]
# ## Summary Statistics
#
# Compare the target team's performance to U11 and all teams.

# %%
# Create summary comparison
# Use exact team name from database if available
target_name_for_stats = None
if 'target_team_season' in locals() and target_team_season:
    target_name_for_stats = target_team_season.team_name
elif 'target_team_name_found' in locals() and target_team_name_found:
    target_name_for_stats = target_team_name_found

if target_name_for_stats and 'df_u11' in locals() and len(df_u11) > 0:
    # Use exact match first
    target_u11 = df_u11[df_u11['team_name'] == target_name_for_stats]
    if len(target_u11) == 0:
        # Fallback to contains
        target_u11 = df_u11[df_u11['team_name'].str.contains(target_name_for_stats, case=False, na=False)]
    if len(target_u11) > 0:
        target_row = target_u11.iloc[0]
        
        print("=" * 80)
        print(f"TARGET TEAM: {target_row['team_name']}")
        print(f"Division: {target_row['division']}")
        print("=" * 80)
        
        metrics = ['goals_for', 'goals_against', 'goal_differential', 'points']
        
        comparison_data = []
        for metric in metrics:
            if metric not in target_row.index:
                continue
                
            target_val = target_row[metric]
            u11_mean = df_u11[metric].mean() if len(df_u11) > 0 and metric in df_u11.columns else 0
            u11_percentile = (df_u11[metric] <= target_val).sum() / len(df_u11) * 100 if len(df_u11) > 0 and metric in df_u11.columns else 0
            
            # Check if df_fall_2025 exists and has data
            if 'df_fall_2025' in locals() and len(df_fall_2025) > 0 and metric in df_fall_2025.columns:
                all_mean = df_fall_2025[metric].mean()
                all_percentile = (df_fall_2025[metric] <= target_val).sum() / len(df_fall_2025) * 100
            else:
                all_mean = 0
                all_percentile = 0
            
            comparison_data.append({
                'Metric': metric.replace('_', ' ').title(),
                'Target Value': target_val,
                'U11 Mean': f"{u11_mean:.1f}",
                'U11 Percentile': f"{u11_percentile:.1f}%",
                'All Teams Mean': f"{all_mean:.1f}",
                'All Teams Percentile': f"{all_percentile:.1f}%",
            })
        
        if comparison_data:
            df_comparison = pd.DataFrame(comparison_data)
            print("\nComparison Summary:")
            print(df_comparison.to_string(index=False))
        
        print("\n" + "=" * 80)
        print("West Coast United Teams Summary:")
        print("=" * 80)
        if 'df_wcu' in locals() and len(df_wcu) > 0:
            required_cols = ['team_name', 'division', 'goals_for', 'goals_against', 'goal_differential', 'points']
            available_cols = [col for col in required_cols if col in df_wcu.columns]
            if available_cols:
                print(df_wcu[available_cols].to_string(index=False))
            else:
                print("No West Coast United teams found in Fall 2025")
        else:
            print("No West Coast United teams found in Fall 2025")
else:
    print("Target team data not available. Please run the previous cells to load team data.")
